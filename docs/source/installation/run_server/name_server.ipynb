# %%
# !PYRO_SERIALIZERS_ACCEPTED=pickle PYRO_PICKLE_PROTOCOL_VERSION=4 pyro4-ns -n 10.225.208.77 -p 8888
# Out:
# Broadcast server running on 0.0.0.0:9091
# NS running on 10.225.208.77:8888 (10.225.208.77)
# ...
# URI = PYRO:Pyro.NameServer@10.225.208.77:8888
